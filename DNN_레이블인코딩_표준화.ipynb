# %%
import numpy as np 
import pandas as pd
import os
import scipy.stats as ss
import matplotlib.pyplot as plt
# import tensorflow as tf
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor,plot_importance
from scipy.stats import f_oneway
import pandas as pd
import datetime

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU에 1GB 메모리만 할당하도록 제한
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024)])
  except RuntimeError as e:
    # 프로그램 시작시에 가상 장치가 설정되어야만 합니다
    print(e)

# %% [markdown]
# # 원핫인코딩

# %% [markdown]
# ### 데이터 전처리

# %%
past_sales = pd.read_csv('C:/Users/PC/표/수요예측/rossmann-store-sales/train.csv')
store = pd.read_csv('C:/Users/PC/표/수요예측/rossmann-store-sales/store.csv')

past_sales['Date'] = pd.to_datetime(past_sales['Date'], format="%Y-%m-%d") # 년도, 달, 일 순으로 format
# a = 공휴일, b = 부활절 공휴일, c = 크리스마스, d = 없음
past_sales['StateHoliday'] = past_sales['StateHoliday'].replace({0:'d'}) # 0 값은 d로 대체
past_sales['StateHoliday'] = past_sales['StateHoliday'].replace({'0':'d'})# 0 값은 d로 대체
past_sales = past_sales.sort_values('Date') # date 기준으로 정렬
# past_sales = pd.get_dummies(data = past_sales,columns=['StateHoliday']) # StateHoliday를 더미 가변수로 대체, 결측값 없다는 거 확인 완료

store = store.drop(['CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'], axis=1)
# store = pd.get_dummies(data = store, columns = ['Assortment']) # 규모를 더미 가변수로 대체, storetype = a에는 규모가 b인 상점은 없음

# 결측값 확인 : past_sales.isnull().sum(), store_a.isnull().sum()
# store의 CompetitionDistance에 3개 있음
# 결측값 : 평균으로 대체
store['CompetitionDistance'] = store['CompetitionDistance'].fillna(store['CompetitionDistance'].mean())

# 병합
data = pd.merge(left = past_sales,right = store, on = 'Store', how = 'right')
# data = pd.get_dummies(data = data, columns = ['DayOfWeek']) # 요일 더미의 가변수로 추가
# data = pd.get_dummies(data = data, columns = ['StoreType'])
data['Month']=pd.DatetimeIndex(data.Date).month
data['Day']=pd.DatetimeIndex(data.Date).day
data = data.drop(['Date'],axis=1) # 그래프 그릴려고 잠시 제거한 코드

pd.options.display.max_columns = None
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(data.StateHoliday)
StateHoliday = le.transform(data.StateHoliday)
data['StateHoliday'] = StateHoliday

le.fit(data.StoreType)
StoreType = le.transform(data.StoreType)
data['StoreType'] = StoreType

le.fit(data.Assortment)
Assortment = le.transform(data.Assortment)
data['Assortment'] = Assortment

# %%
scaler = StandardScaler().fit(data)
data = pd.DataFrame(scaler.transform(data),index = data.index, columns = data.columns)

# %%
data
# Out:
#            Store  DayOfWeek     Sales  Customers      Open     Promo  \
# 0       -1.73164  -1.000476 -1.499723  -1.363330 -2.210440 -0.785400
# 1       -1.73164  -0.499823 -0.063331   0.075050  0.452399 -0.785400
# 2       -1.73164   0.000831 -0.375805  -0.118744  0.452399 -0.785400
# 3       -1.73164   0.501484 -0.334505  -0.030460  0.452399 -0.785400
# 4       -1.73164   1.002138 -0.201775   0.003992  0.452399 -0.785400
# ...          ...        ...       ...        ...       ...       ...
# 1017204  1.72897  -1.501129  1.282670  -0.054146  0.452399  1.273237
# 1017205  1.72897  -1.000476  0.602397  -0.286698  0.452399  1.273237
# 1017206  1.72897  -0.499823  0.490187  -0.344836  0.452399  1.273237
# 1017207  1.72897   0.000831  0.683437  -0.282392  0.452399  1.273237
# 1017208  1.72897   0.501484  0.754867  -0.204874  0.452399  1.273237
#
#          StateHoliday  SchoolHoliday  StoreType  Assortment  \
# 0           -6.476950       2.144211   0.580451   -0.940975
# 1            0.170475       2.144211   0.580451   -0.940975
# 2            0.170475       2.144211   0.580451   -0.940975
# 3            0.170475       2.144211   0.580451   -0.940975
# 4            0.170475       2.144211   0.580451   -0.940975
# ...               ...            ...        ...         ...
# 1017204      0.170475       2.144211   1.312850    1.071502
# 1017205      0.170475       2.144211   1.312850    1.071502
# 1017206      0.170475       2.144211   1.312850    1.071502
# 1017207      0.170475       2.144211   1.312850    1.071502
# 1017208      0.170475       2.144211   1.312850    1.071502
#
#          CompetitionDistance    Promo2     Month       Day
# 0                  -0.539891 -1.001128 -1.457193 -1.673123
# 1                  -0.539891 -1.001128 -1.457193 -1.559327
# 2                  -0.539891 -1.001128 -1.457193 -1.445530
# 3                  -0.539891 -1.001128 -1.457193 -1.331734
# 4                  -0.539891 -1.001128 -1.457193 -1.217938
# ...                      ...       ...       ...       ...
# 1017204            -0.010385  0.998873  0.346724  1.285581
# 1017205            -0.010385  0.998873  0.346724  1.399377
# 1017206            -0.010385  0.998873  0.346724  1.513173
# 1017207            -0.010385  0.998873  0.346724  1.626969
# 1017208            -0.010385  0.998873  0.346724  1.740766
#
# [1017209 rows x 14 columns]

# %%
target_col = 'Sales'
features_cols = data.columns.drop(target_col)        
features = data[features_cols]
target = data[target_col]
target = pd.DataFrame(target.values.reshape(-1,1))
features = features.values
target = target.values
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=34)
x_test,x_valid,y_test,y_valid = train_test_split(x_test, y_test, test_size=0.5)

# %%
x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)
x_valid = x_valid.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)
y_valid = y_valid.astype(np.float32)

# %%
print('train_data의 row : %s, column : %s'%(x_train.shape[0],x_train.shape[1]))
print('test_data의 row : %s, column : %s'%(x_test.shape[0],x_test.shape[1]))
print('val_data의 row : %s, column : %s'%(x_valid.shape[0],x_valid.shape[1]))
# Out:
# train_data의 row : 813767, column : 13
# test_data의 row : 101721, column : 13
# val_data의 row : 101721, column : 13

# %% [markdown]
# ### 학습

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(256,input_dim = x_train.shape[1],activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(256,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(256,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(128,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(1))

model.compile(optimizer='adam',
             loss='mse',
             metrics=['mean_absolute_error'])

model_path = 'C:/project/rossmann-store-sales'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=model_path , monitor='val_mean_absolute_error', verbose=1, save_best_only=True)
# early_stopping = EarlyStopping(monitor='val_loss', patience=6)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               3584
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 171,777
# Trainable params: 169,985
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
start = datetime.datetime.now()

results= model.fit(x_train, y_train,
                    validation_data=(x_valid, y_valid),
                    batch_size=64,
                    epochs=50,
                   callbacks=[checkpoint])

end = datetime.datetime.now()
time = end-start
print("처리시간 : ", time)
# Out:
# Epoch 1/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.1340 - mean_absolute_error: 0.2584
# Epoch 00001: val_mean_absolute_error improved from inf to 0.17062, saving model to C:/project\rossmann-store-sales
# WARNING:tensorflow:From C:\Users\PC\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\PC\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 114s 9ms/step - loss: 0.1340 - mean_absolute_error: 0.2584 - val_loss: 0.0685 - val_mean_absolute_error: 0.1706
# Epoch 2/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.0928 - mean_absolute_error: 0.2229
# Epoch 00002: val_mean_absolute_error did not improve from 0.17062
# 12716/12716 [==============================] - 110s 9ms/step - loss: 0.0928 - mean_absolute_error: 0.2229 - val_loss: 0.0638 - val_mean_absolute_error: 0.1834
# Epoch 3/50
# 12712/12716 [============================>.] - ETA: 0s - loss: 0.0863 - mean_absolute_error: 0.2162
# Epoch 00003: val_mean_absolute_error improved from 0.17062 to 0.15666, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 112s 9ms/step - loss: 0.0863 - mean_absolute_error: 0.2162 - val_loss: 0.0644 - val_mean_absolute_error: 0.1567
# Epoch 4/50
# 12711/12716 [============================>.] - ETA: 0s - loss: 0.0820 - mean_absolute_error: 0.2111
# Epoch 00004: val_mean_absolute_error improved from 0.15666 to 0.15565, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 123s 10ms/step - loss: 0.0820 - mean_absolute_error: 0.2111 - val_loss: 0.0559 - val_mean_absolute_error: 0.1556
# Epoch 5/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0796 - mean_absolute_error: 0.2086- ETA: 1s - loss: 0.079
# Epoch 00005: val_mean_absolute_error did not improve from 0.15565
# 12716/12716 [==============================] - 105s 8ms/step - loss: 0.0796 - mean_absolute_error: 0.2086 - val_loss: 0.0615 - val_mean_absolute_error: 0.1639
# Epoch 6/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.0776 - mean_absolute_error: 0.2064
# Epoch 00006: val_mean_absolute_error did not improve from 0.15565
# 12716/12716 [==============================] - 89s 7ms/step - loss: 0.0776 - mean_absolute_error: 0.2064 - val_loss: 0.0550 - val_mean_absolute_error: 0.1735
# Epoch 7/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0759 - mean_absolute_error: 0.2043
# Epoch 00007: val_mean_absolute_error improved from 0.15565 to 0.14299, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 119s 9ms/step - loss: 0.0759 - mean_absolute_error: 0.2043 - val_loss: 0.0513 - val_mean_absolute_error: 0.1430
# Epoch 8/50
# 12712/12716 [============================>.] - ETA: 0s - loss: 0.0748 - mean_absolute_error: 0.2031
# Epoch 00008: val_mean_absolute_error did not improve from 0.14299
# 12716/12716 [==============================] - 105s 8ms/step - loss: 0.0748 - mean_absolute_error: 0.2031 - val_loss: 0.0602 - val_mean_absolute_error: 0.1594
# Epoch 9/50
# 12711/12716 [============================>.] - ETA: 0s - loss: 0.0734 - mean_absolute_error: 0.2011
# Epoch 00009: val_mean_absolute_error improved from 0.14299 to 0.13719, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 88s 7ms/step - loss: 0.0734 - mean_absolute_error: 0.2011 - val_loss: 0.0456 - val_mean_absolute_error: 0.1372
# Epoch 10/50
# 12712/12716 [============================>.] - ETA: 0s - loss: 0.0721 - mean_absolute_error: 0.1993
# Epoch 00010: val_mean_absolute_error did not improve from 0.13719
# 12716/12716 [==============================] - 111s 9ms/step - loss: 0.0721 - mean_absolute_error: 0.1993 - val_loss: 0.0574 - val_mean_absolute_error: 0.1524
# Epoch 11/50
# 12705/12716 [============================>.] - ETA: 0s - loss: 0.0718 - mean_absolute_error: 0.1989
# Epoch 00011: val_mean_absolute_error did not improve from 0.13719
# 12716/12716 [==============================] - 105s 8ms/step - loss: 0.0718 - mean_absolute_error: 0.1989 - val_loss: 0.0661 - val_mean_absolute_error: 0.1446
# Epoch 12/50
# 12711/12716 [============================>.] - ETA: 0s - loss: 0.0704 - mean_absolute_error: 0.1973
# Epoch 00012: val_mean_absolute_error did not improve from 0.13719
# 12716/12716 [==============================] - 114s 9ms/step - loss: 0.0704 - mean_absolute_error: 0.1973 - val_loss: 0.0548 - val_mean_absolute_error: 0.1595
# Epoch 13/50
# 12711/12716 [============================>.] - ETA: 0s - loss: 0.0707 - mean_absolute_error: 0.1978
# Epoch 00013: val_mean_absolute_error did not improve from 0.13719
# 12716/12716 [==============================] - 117s 9ms/step - loss: 0.0707 - mean_absolute_error: 0.1978 - val_loss: 0.0490 - val_mean_absolute_error: 0.1466
# Epoch 14/50
# 12706/12716 [============================>.] - ETA: 0s - loss: 0.0701 - mean_absolute_error: 0.1971
# Epoch 00014: val_mean_absolute_error did not improve from 0.13719
# 12716/12716 [==============================] - 120s 9ms/step - loss: 0.0701 - mean_absolute_error: 0.1971 - val_loss: 0.0531 - val_mean_absolute_error: 0.1393
# Epoch 15/50
# 12714/12716 [============================>.] - ETA: 0s - loss: 0.0694 - mean_absolute_error: 0.1961
# Epoch 00015: val_mean_absolute_error improved from 0.13719 to 0.13385, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 127s 10ms/step - loss: 0.0694 - mean_absolute_error: 0.1961 - val_loss: 0.0549 - val_mean_absolute_error: 0.1339
# Epoch 16/50
# 12710/12716 [============================>.] - ETA: 0s - loss: 0.0684 - mean_absolute_error: 0.1946
# Epoch 00016: val_mean_absolute_error did not improve from 0.13385
# 12716/12716 [==============================] - 127s 10ms/step - loss: 0.0684 - mean_absolute_error: 0.1946 - val_loss: 0.1011 - val_mean_absolute_error: 0.1517
# Epoch 17/50
# 12714/12716 [============================>.] - ETA: 0s - loss: 0.0683 - mean_absolute_error: 0.1945
# Epoch 00017: val_mean_absolute_error did not improve from 0.13385
# 12716/12716 [==============================] - 119s 9ms/step - loss: 0.0683 - mean_absolute_error: 0.1945 - val_loss: 0.0491 - val_mean_absolute_error: 0.1445
# Epoch 18/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0678 - mean_absolute_error: 0.1939
# Epoch 00018: val_mean_absolute_error did not improve from 0.13385
# 12716/12716 [==============================] - 117s 9ms/step - loss: 0.0678 - mean_absolute_error: 0.1939 - val_loss: 0.0525 - val_mean_absolute_error: 0.1416
# Epoch 19/50
# 12704/12716 [============================>.] - ETA: 0s - loss: 0.0674 - mean_absolute_error: 0.1933
# Epoch 00019: val_mean_absolute_error improved from 0.13385 to 0.12671, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 115s 9ms/step - loss: 0.0674 - mean_absolute_error: 0.1933 - val_loss: 0.0550 - val_mean_absolute_error: 0.1267
# Epoch 20/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.0672 - mean_absolute_error: 0.1931
# Epoch 00020: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 115s 9ms/step - loss: 0.0672 - mean_absolute_error: 0.1931 - val_loss: 0.0506 - val_mean_absolute_error: 0.1386
# Epoch 21/50
# 12711/12716 [============================>.] - ETA: 0s - loss: 0.0673 - mean_absolute_error: 0.1933
# Epoch 00021: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 119s 9ms/step - loss: 0.0673 - mean_absolute_error: 0.1933 - val_loss: 0.0496 - val_mean_absolute_error: 0.1375
# Epoch 22/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0662 - mean_absolute_error: 0.1916- ETA
# Epoch 00022: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 115s 9ms/step - loss: 0.0662 - mean_absolute_error: 0.1916 - val_loss: 0.0553 - val_mean_absolute_error: 0.1314
# Epoch 23/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0662 - mean_absolute_error: 0.1918
# Epoch 00023: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 123s 10ms/step - loss: 0.0662 - mean_absolute_error: 0.1918 - val_loss: 0.0510 - val_mean_absolute_error: 0.1422
# Epoch 24/50
# 12714/12716 [============================>.] - ETA: 0s - loss: 0.0659 - mean_absolute_error: 0.1912
# Epoch 00024: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 124s 10ms/step - loss: 0.0659 - mean_absolute_error: 0.1912 - val_loss: 0.0592 - val_mean_absolute_error: 0.1444
# Epoch 25/50
# 12712/12716 [============================>.] - ETA: 0s - loss: 0.0660 - mean_absolute_error: 0.1917
# Epoch 00025: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 113s 9ms/step - loss: 0.0660 - mean_absolute_error: 0.1917 - val_loss: 0.0477 - val_mean_absolute_error: 0.1320
# Epoch 26/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0655 - mean_absolute_error: 0.1908
# Epoch 00026: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 114s 9ms/step - loss: 0.0655 - mean_absolute_error: 0.1908 - val_loss: 0.0562 - val_mean_absolute_error: 0.1299
# Epoch 27/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.0651 - mean_absolute_error: 0.1900
# Epoch 00027: val_mean_absolute_error did not improve from 0.12671
# 12716/12716 [==============================] - 120s 9ms/step - loss: 0.0651 - mean_absolute_error: 0.1900 - val_loss: 0.0711 - val_mean_absolute_error: 0.1316
# Epoch 28/50
# 12711/12716 [============================>.] - ETA: 0s - loss: 0.0650 - mean_absolute_error: 0.1899
# Epoch 00028: val_mean_absolute_error improved from 0.12671 to 0.12585, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 114s 9ms/step - loss: 0.0650 - mean_absolute_error: 0.1899 - val_loss: 0.0510 - val_mean_absolute_error: 0.1259
# Epoch 29/50
# 12712/12716 [============================>.] - ETA: 0s - loss: 0.0646 - mean_absolute_error: 0.1893
# Epoch 00029: val_mean_absolute_error did not improve from 0.12585
# 12716/12716 [==============================] - 127s 10ms/step - loss: 0.0646 - mean_absolute_error: 0.1893 - val_loss: 0.0607 - val_mean_absolute_error: 0.1354
# Epoch 30/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.0650 - mean_absolute_error: 0.1902
# Epoch 00030: val_mean_absolute_error did not improve from 0.12585
# 12716/12716 [==============================] - 124s 10ms/step - loss: 0.0650 - mean_absolute_error: 0.1902 - val_loss: 0.0690 - val_mean_absolute_error: 0.1491
# Epoch 31/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0642 - mean_absolute_error: 0.1888
# Epoch 00031: val_mean_absolute_error did not improve from 0.12585
# 12716/12716 [==============================] - 104s 8ms/step - loss: 0.0642 - mean_absolute_error: 0.1888 - val_loss: 0.0532 - val_mean_absolute_error: 0.1375
# Epoch 32/50
# 12710/12716 [============================>.] - ETA: 0s - loss: 0.0643 - mean_absolute_error: 0.1888
# Epoch 00032: val_mean_absolute_error improved from 0.12585 to 0.11796, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 133s 10ms/step - loss: 0.0643 - mean_absolute_error: 0.1888 - val_loss: 0.0462 - val_mean_absolute_error: 0.1180
# Epoch 33/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0640 - mean_absolute_error: 0.1883
# Epoch 00033: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 120s 9ms/step - loss: 0.0640 - mean_absolute_error: 0.1883 - val_loss: 0.0539 - val_mean_absolute_error: 0.1213
# Epoch 34/50
# 12714/12716 [============================>.] - ETA: 0s - loss: 0.0636 - mean_absolute_error: 0.1881
# Epoch 00034: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 120s 9ms/step - loss: 0.0636 - mean_absolute_error: 0.1881 - val_loss: 0.0550 - val_mean_absolute_error: 0.1339
# Epoch 35/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0638 - mean_absolute_error: 0.1883
# Epoch 00035: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 121s 9ms/step - loss: 0.0638 - mean_absolute_error: 0.1883 - val_loss: 0.0506 - val_mean_absolute_error: 0.1344
# Epoch 36/50
# 12711/12716 [============================>.] - ETA: 0s - loss: 0.0638 - mean_absolute_error: 0.1883
# Epoch 00036: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 123s 10ms/step - loss: 0.0638 - mean_absolute_error: 0.1883 - val_loss: 0.0441 - val_mean_absolute_error: 0.1367
# Epoch 37/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.0635 - mean_absolute_error: 0.1878
# Epoch 00037: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 124s 10ms/step - loss: 0.0635 - mean_absolute_error: 0.1878 - val_loss: 0.0706 - val_mean_absolute_error: 0.1260
# Epoch 38/50
# 12712/12716 [============================>.] - ETA: 0s - loss: 0.0633 - mean_absolute_error: 0.1877
# Epoch 00038: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 123s 10ms/step - loss: 0.0633 - mean_absolute_error: 0.1877 - val_loss: 0.0571 - val_mean_absolute_error: 0.1303
# Epoch 39/50
# 12714/12716 [============================>.] - ETA: 0s - loss: 0.0629 - mean_absolute_error: 0.1868
# Epoch 00039: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 124s 10ms/step - loss: 0.0629 - mean_absolute_error: 0.1868 - val_loss: 0.0553 - val_mean_absolute_error: 0.1356
# Epoch 40/50
# 12714/12716 [============================>.] - ETA: 0s - loss: 0.0629 - mean_absolute_error: 0.1871
# Epoch 00040: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 122s 10ms/step - loss: 0.0629 - mean_absolute_error: 0.1871 - val_loss: 0.0439 - val_mean_absolute_error: 0.1383
# Epoch 41/50
# 12716/12716 [==============================] - ETA: 0s - loss: 0.0628 - mean_absolute_error: 0.1869
# Epoch 00041: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 124s 10ms/step - loss: 0.0628 - mean_absolute_error: 0.1869 - val_loss: 0.0477 - val_mean_absolute_error: 0.1314
# Epoch 42/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0627 - mean_absolute_error: 0.1865
# Epoch 00042: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 122s 10ms/step - loss: 0.0627 - mean_absolute_error: 0.1865 - val_loss: 0.0542 - val_mean_absolute_error: 0.1220
# Epoch 43/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0626 - mean_absolute_error: 0.1865
# Epoch 00043: val_mean_absolute_error did not improve from 0.11796
# 12716/12716 [==============================] - 124s 10ms/step - loss: 0.0626 - mean_absolute_error: 0.1864 - val_loss: 0.0548 - val_mean_absolute_error: 0.1394
# Epoch 44/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0629 - mean_absolute_error: 0.1870
# Epoch 00044: val_mean_absolute_error improved from 0.11796 to 0.11748, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 125s 10ms/step - loss: 0.0629 - mean_absolute_error: 0.1870 - val_loss: 0.0505 - val_mean_absolute_error: 0.1175
# Epoch 45/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0626 - mean_absolute_error: 0.1865
# Epoch 00045: val_mean_absolute_error did not improve from 0.11748
# 12716/12716 [==============================] - 132s 10ms/step - loss: 0.0626 - mean_absolute_error: 0.1865 - val_loss: 0.0627 - val_mean_absolute_error: 0.1200
# Epoch 46/50
# 12712/12716 [============================>.] - ETA: 0s - loss: 0.0623 - mean_absolute_error: 0.1863- ETA: 1s - loss: 0.0623
# Epoch 00046: val_mean_absolute_error did not improve from 0.11748
# 12716/12716 [==============================] - 133s 10ms/step - loss: 0.0623 - mean_absolute_error: 0.1863 - val_loss: 0.0741 - val_mean_absolute_error: 0.1390
# Epoch 47/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0617 - mean_absolute_error: 0.1853
# Epoch 00047: val_mean_absolute_error did not improve from 0.11748
# 12716/12716 [==============================] - 130s 10ms/step - loss: 0.0617 - mean_absolute_error: 0.1853 - val_loss: 0.0598 - val_mean_absolute_error: 0.1225
# Epoch 48/50
# 12713/12716 [============================>.] - ETA: 0s - loss: 0.0620 - mean_absolute_error: 0.1860
# Epoch 00048: val_mean_absolute_error improved from 0.11748 to 0.11538, saving model to C:/project\rossmann-store-sales
# INFO:tensorflow:Assets written to: C:/project\rossmann-store-sales\assets
# 12716/12716 [==============================] - 133s 10ms/step - loss: 0.0620 - mean_absolute_error: 0.1860 - val_loss: 0.0540 - val_mean_absolute_error: 0.1154
# Epoch 49/50
# 12708/12716 [============================>.] - ETA: 0s - loss: 0.0624 - mean_absolute_error: 0.1863
# Epoch 00049: val_mean_absolute_error did not improve from 0.11538
# 12716/12716 [==============================] - 131s 10ms/step - loss: 0.0624 - mean_absolute_error: 0.1863 - val_loss: 0.0581 - val_mean_absolute_error: 0.1325
# Epoch 50/50
# 12715/12716 [============================>.] - ETA: 0s - loss: 0.0616 - mean_absolute_error: 0.1852
# Epoch 00050: val_mean_absolute_error did not improve from 0.11538
# 12716/12716 [==============================] - 130s 10ms/step - loss: 0.0616 - mean_absolute_error: 0.1852 - val_loss: 0.0455 - val_mean_absolute_error: 0.1283
# 처리시간 :  1:39:06.498234

# %% [markdown]
# ### 평가 : 테스트 데이터로

# %%
pred= model.predict(x_test)

# %%
pred_365 = pred[0:365]
y_test_365 = y_test[0:365]

fig = plt.figure(facecolor='white')
ax = fig.add_subplot(111)
ax.plot(y_test_365, label='True')
ax.plot(pred_365, label='Prediction')

ax.legend()
plt.show()

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, pred)
print(r2)
# Out:
# 0.9554847511735255

# %%
mse = mean_squared_error(pred, y_valid, squared=False)
print(mse)
# Out:
# 1.3892953
